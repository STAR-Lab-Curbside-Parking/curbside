# %%
import folium
import folium.plugins

from matplotlib import pyplot as plt
import pandas as pd
import xml.etree.ElementTree as ET

net_xml = "seattle.net.xml"
add_xml = "seattle.add.xml"

# %% [markdown]
# #### Transaction investigation

# %%
park_transaction = pd.read_csv("seattle_transactions.csv")

# %%
park_transaction['Transaction DateTime'] = pd.to_datetime(park_transaction['Transaction DateTime'])

# %% [markdown]
# #### temporal distribution

# %%
boundary = [(47.612799, 47.618586), (-122.352507,-122.343548)]

# define by block names and by bounding box
study_area_trans = park_transaction[
    (park_transaction['Blockface Name'].str.contains('1|2|3|4')) & \
    (park_transaction['Blockface Name'].str.contains('CEDAR|VINE|WALL|BATTERY')) &\
    (park_transaction['Latitude'].between(boundary[0][0], boundary[0][1], inclusive=True)) & \
    (park_transaction['Longitude'].between(boundary[1][0], boundary[1][1], inclusive=True)) & \
    (park_transaction['Blockface Name'].str.contains('5|6|ALASKAN|WESTERN|ELLIOT') == False)
]

# %% [markdown]
# ##### Seattle 10/28 - 11/03 (a week)

# %%
fig, ax = plt.subplots()

park_transaction['Transaction DateTime'].dt.hour.hist(ax=ax, grid=False)
ax.set_xlabel('Hour')
ax.set_ylabel('Count')
ax.set_title('Histogram on parking transaction hours in Seattle\n{} - {}'.format(
    study_area_trans['Transaction DateTime'].dt.date.min(), study_area_trans['Transaction DateTime'].dt.date.max()))

plt.show()

# %% [markdown]
# ##### Demo area 10/28 - 11/03 (a week)

# %%
fig, ax = plt.subplots()

study_area_trans['Transaction DateTime'].dt.hour.hist(ax=ax, grid=False)
ax.set_xlabel('Hour')
ax.set_ylabel('Count')
ax.set_title('Histogram on parking transaction hours in Belltown demo area\n{} - {}'.format(
    study_area_trans['Transaction DateTime'].dt.date.min(), study_area_trans['Transaction DateTime'].dt.date.max()))

plt.show()

# %%
fig, ax = plt.subplots()

study_area_trans['Transaction DateTime'].dt.hour.hist(ax=ax, grid=False, density=1)
ax.set_xlabel('Hour')
ax.set_ylabel('Count')
ax.set_title('Histogram on parking transaction hours in Belltown demo area\n{} - {}'.format(
    study_area_trans['Transaction DateTime'].dt.date.min(), study_area_trans['Transaction DateTime'].dt.date.max()))

plt.show()

# %% [markdown]
# #### spatial distribution

# %%
study_area_trans
# Out:
#         Transaction ID  Meter Code Transaction DateTime Payment Mean  \
# 59           901820472    10052004  2020-10-28 06:12:00  CREDIT CARD
# 164          901839288    10282004  2020-10-28 07:50:00  CREDIT CARD
# 170          901839349    10209004  2020-10-28 07:51:00  CREDIT CARD
# 253          901844416    10207004  2020-10-28 08:06:00        PHONE
# 261          901844484    10299004  2020-10-28 08:06:00        PHONE
# ...                ...         ...                  ...          ...
# 141656       904026887    10210004  2020-11-03 19:38:00        PHONE
# 141667       904027072    10506004  2020-11-03 19:40:00        PHONE
# 141676       904027327    10268004  2020-11-03 19:43:00        PHONE
# 141702       904028217    10122004  2020-11-03 19:51:00        PHONE
# 141705       904028264    10206004  2020-11-03 19:52:00        PHONE
#
#         Amount Paid  Duration In Minutes  \
# 59             2.00                  240
# 164            0.50                   60
# 170            2.00                  240
# 253            0.25                   30
# 261            0.62                   75
# ...             ...                  ...
# 141656         0.17                   20
# 141667         0.17                   20
# 141676         0.14                   17
# 141702         0.08                    9
# 141705         0.07                    8
#
#                                 Blockface Name Side Of Street  Element key  \
# 59      4TH AVE BETWEEN BELL ST AND BATTERY ST             NE        28954
# 164        VINE ST BETWEEN 1ST AVE AND 2ND AVE             NW        58617
# 170        2ND AVE BETWEEN WALL ST AND VINE ST             SW         2781
# 253        2ND AVE BETWEEN WALL ST AND VINE ST             NE         2782
# 261       CEDAR ST BETWEEN 2ND AVE AND 3RD AVE             SE        54954
# ...                                        ...            ...          ...
# 141656    2ND AVE BETWEEN VINE ST AND CEDAR ST             NE        25718
# 141667     WALL ST BETWEEN 1ST AVE AND 2ND AVE             SE        13346
# 141676  BATTERY ST BETWEEN 2ND AVE AND 3RD AVE             SE        76986
# 141702     1ST AVE BETWEEN WALL ST AND VINE ST             SW        24045
# 141705  2ND AVE BETWEEN BATTERY ST AND WALL ST             NE        70754
#
#         Parking Space Number   Latitude   Longitude
# 59                       NaN  47.615819 -122.344487
# 164                      NaN  47.615651 -122.349293
# 170                      NaN  47.615585 -122.348439
# 253                      NaN  47.615696 -122.348301
# 261                      NaN  47.616735 -122.349248
# ...                      ...        ...         ...
# 141656                   NaN  47.616245 -122.349211
# 141667                   NaN  47.615003 -122.348237
# 141676                   NaN  47.615079 -122.346443
# 141702                   NaN  47.614928 -122.349306
# 141705                   NaN  47.615118 -122.347316
#
# [6279 rows x 12 columns]

# %%
belltown = folium.Map([sum(boundary[0])/2, sum(boundary[1])/2], zoom_start=16, tiles='CartoDB positron')

belltown.add_child(folium.plugins.HeatMap(study_area_trans[['Latitude', 'Longitude']], radius=20, blur=35))

belltown
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
